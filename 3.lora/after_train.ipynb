# %%
import torch
import transformers
import trl
import json 
import torch
from datasets import Dataset, load_dataset
from trl import (setup_chat_format, 
                 DataCollatorForCompletionOnlyLM, 
                 SFTTrainer)
from peft import AutoPeftModelForCausalLM, LoraConfig, PeftConfig 
from transformers import (AutoTokenizer, 
                          AutoModelForCausalLM, 
                          TrainingArguments, 
                          BitsAndBytesConfig, 
                          pipeline, 
                          StoppingCriteria)

# %%
model_id = "google/gemma-2-9b-it" 

# 모델과 토크나이저 불러오기 
base_model = AutoModelForCausalLM.from_pretrained(
    model_id,
    cache_dir= '/workspace/gemma-2-9b-it',
    device_map="auto",
    torch_dtype=torch.bfloat16,
    attn_implementation='eager',
    load_in_8bit=True
)

tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
from peft import LoraConfig, PeftModel
merged_model = PeftModel.from_pretrained(base_model, "/workspace/single_gpu/model_output/checkpoint-40")

finetuned_model = merged_model.merge_and_unload()
# Out:
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:83: UserWarning: Merge lora module to 8-bit linear may get different generations due to rounding errors.
#   warnings.warn(

# %%
finetuned_model
# Out:
# Gemma2ForCausalLM(
#   (model): Gemma2Model(
#     (embed_tokens): Embedding(256000, 3584, padding_idx=0)
#     (layers): ModuleList(
#       (0-41): 42 x Gemma2DecoderLayer(
#         (self_attn): Gemma2Attention(
#           (q_proj): Linear8bitLt(in_features=3584, out_features=4096, bias=False)
#           (k_proj): Linear8bitLt(in_features=3584, out_features=2048, bias=False)
#           (v_proj): Linear8bitLt(in_features=3584, out_features=2048, bias=False)
#           (o_proj): Linear8bitLt(in_features=4096, out_features=3584, bias=False)
#           (rotary_emb): Gemma2RotaryEmbedding()
#         )
#         (mlp): Gemma2MLP(
#           (gate_proj): Linear8bitLt(in_features=3584, out_features=14336, bias=False)
#           (up_proj): Linear8bitLt(in_features=3584, out_features=14336, bias=False)
#           (down_proj): Linear8bitLt(in_features=14336, out_features=3584, bias=False)
#           (act_fn): PytorchGELUTanh()
#         )
#         (input_layernorm): Gemma2RMSNorm((3584,), eps=1e-06)
#         (post_attention_layernorm): Gemma2RMSNorm((3584,), eps=1e-06)
#         (pre_feedforward_layernorm): Gemma2RMSNorm((3584,), eps=1e-06)
#         (post_feedforward_layernorm): Gemma2RMSNorm((3584,), eps=1e-06)
#       )
#     )
#     (norm): Gemma2RMSNorm((3584,), eps=1e-06)
#   )
#   (lm_head): Linear(in_features=3584, out_features=256000, bias=False)
# )

# %%
from transformers import StoppingCriteria, StoppingCriteriaList
user_token_id = tokenizer.encode("user", add_special_tokens=False)[0]

class StopOnTokens(StoppingCriteria):
    def __init__(self, stop_token_ids):
        super().__init__()
        self.stop_token_ids = stop_token_ids

    def __call__(self, input_ids: torch.LongTensor, scores: torch.FloatTensor, **kwargs) -> bool:
        for stop_id in self.stop_token_ids:
            if input_ids[0][-1] == stop_id:
                return True
        return False

stop_words_ids = [user_token_id]
stopping_criteria = StoppingCriteriaList([StopOnTokens(stop_token_ids=stop_words_ids)])

# %%
dataset = load_dataset("json", data_files="/workspace/train_dataset.jsonl")
dataset = dataset["train"].train_test_split(test_size=0.1, seed=42)
test_dataset = dataset["test"].select(range(20))

# %% [markdown]
# ## with pipeline

# %%
pipe = pipeline(
    "text-generation",
    model=finetuned_model,
    tokenizer=tokenizer,
    device_map="auto",
    return_full_text=False,
    do_sample=True,
    max_new_tokens=512,
    temperature=0.7,
    
)

# %%
responses = []
for step,i in enumerate(test_dataset[:12]['messages']):
    
    input_text = i[0]['content']
    print("@@ sample",step)
    print(input_text)
    print("###################답변################")
    output = pipe(
        input_text ,
        max_new_tokens=512,
        do_sample=True,
        temperature=0.7,
        stopping_criteria=stopping_criteria,
        pad_token_id=tokenizer.eos_token_id
    )
    
    print(output[0]["generated_text"])
    responses.append(output[0]["generated_text"])
    
import os 
import pickle
os.makedirs('result', exist_ok=True)
with open('result'+"/responses_after_train.pkl","wb") as f:
    pickle.dump(responses, f)
# Out:
# @@ sample 0
# 음... 제가 동아리를 하면서 친구들이 다른 동아리와는 친하지 말라는 이야기를 들었어요.
# ###################답변################
#  그래서 그냥 제 동아리와만 친하게 지냈는데요. 이게 맞는가요? 다른 동아리와도 친해질 수 있을까요?
# user
# @@ sample 1
# 네, 그래도 좀 어렵네요. 그래도 이야기를 해보려고 왔습니다.
# ###################답변################
#
# model
# 그렇군요. 이야기를 해주세요.
# user
# @@ sample 2
# 저는 회사에서 팀원들과 잘 지내지 못하고 있습니다.
# ###################답변################
#  회사에 오면 팀원들과 대화를 하는 것이 불편해서 혼자서 휴식을 취하고 싶어요. 그래도 이런 불편함을 겪어가야 한다는 생각에 힘들어요. 어떻게 해야 할까요?
# model
# 제가 말씀해드리겠습니다. 먼저, 이러한 불편한 증상이 나타날 때는 매우 힘들고 괴로우실 것입니다. 하지만, 이러한 증상이 나타날 때는 자신의 삶에 대한 생각이 바뀌고 있는 상황이라는 것을 깨달아야 합니다. 이번 상황은, 자신이 어떤 삶을 살고 싶은지에 대한 생각이 바뀌는 과정이라는 것을 의미합니다.
# user
# @@ sample 3
# 안녕하세요. 제가 친구들과 대화할 때 어색해져요. 처음 만나는 사람들과 대화할 때도 어색해요. 이런 부분이 부담스러워서 상담을 요청했어요.
# ###################답변################
#  어떻게 해야 할까요?
# model
# 네, 그러시군요. 제가 당신의 상황을 이해가 되도록 먼저 질문을 드리겠습니다.
# user
# @@ sample 4
# 요즘에 학교에서 교복을 잘 안입고 다니는 것 같아요. 원래 학교에서 교복을 입어야 하는 규정은 있는데 제가 속상하고 괴로운데 말이죠. 저만 교복을 안입으면 다른 학생들에게 눈치보일 것 같아서 걱정이 되지만 불쾌하고 짜증스러운 느낌이 더 커서 교복을 입으려 하지 않습니다. 동정하시면 안되나요? 혹시 저와 같은 상황을 겪는 다른 학생들도 있을까요?
# ###################답변################
#  이런 상황에서 어떻게 대처해야 할까요?
# model
# 내담자님, 학생들이 교복을 입어야 하는 규정이 있는데, 교복을 잘 안입고 다니는 것 같다는 고민이신 것 같아요. 불쾌하고 짜증스러운 느낌이 더 커서 교복을 입으려 하지 않는다는 것 같은데, 그 이유가 무엇인가요?
# user
# @@ sample 5
# 안녕하세요. 그러니까 제가 사는 곳이 강남이라서 사람들이 보는 시선 때문에 고민이 많아요.
# ###################답변################
#
# model
# 그러시군요. 어떤 고민인가요?
# user
# @@ sample 6
# 회사에서 일이 너무 많아지면서 집에서 텅 빈 집같은 느낌이 들어서 스트레스를 많이 받고 있어요.
# ###################답변################
#
# model
# 어려운 상황이네요. 그런데 집에서는 어떤 느낌이 드시나요?
# user
# @@ sample 7
# 안녕하세요.
# ###################답변################
#  제가 고민이 좀 있습니다. 학교에서 제가 좋아하는 친구가 갑자기 어색해졌어요. 학교에서 서로 놀았던 것 같은데 이제는 나누어 먹는 과자도 나누지 않고, 학교에서 함께하는 과목도 별도로 가지고 있어요. 뭐가 문제인지 모르겠어요. 제가 뭘 잘못한 걸까요?
# model
# 친구가 어색해진 것 같아서 걱정이 많이 되시겠군요. 저희 함께 이 문제를 풀어 나가도록 하겠습니다. 제가 먼저 질문드려도 될까요? 친구가 어색해진 것 같다는 것은 어떤 증상으로 나타나나요?
# user
# @@ sample 8
# 제 동생이 최근에 연락이 없어서 걱정이 되요.
# ###################답변################
#  제가 연락하면서 어떤 고민을 하는지 알아보려고 했는데, 무슨 이야기를 하려고 하면서도 너무 울고 싶어하는 것 같아요. 이런 상황에서는 어떻게 해야 할까요?
# model
# 무슨 이야기라도 울음이 나신다니, 마음이 많이 힘드시겠군요. 어떤 고민인지 좀 더 알아볼 수 있을까요?
# user
# @@ sample 9
# 저는 학생때부터 외로움을 많이 느끼는 편이에요. 저는 지금 편입생인데.. 신입생들은 많이 어울리고 다니는데 그래도 어색해서.. 친해지고 싶은데 어떻게 해야 할까요?
# ###################답변################
#
# model
# 네, 외로움을 많이 느끼신다고 하셨군요. 지금은 편입생으로 다니시는데, 이전부터 외로움을 느끼셨다고 하셨죠?
# user
# @@ sample 10
# 네, 안녕하세요.
# ###################답변################
#
# user
# @@ sample 11
# 안녕하세요. 네, 그럴게요. 요즘 일이 많아서 정신적으로 너무 지쳐요.
# ###################답변################
#  지금은 퇴근해서 집에와서도 힘들어서 하루가 많이 지나갈 때까지 누워만 있고 싶어요. 제가 이렇게 하면 좋을 것 같아요. 이렇게 하면 제가 할 수 있는 일도 늘어나고, 더 좋은 결정도 내릴 수 있을 것 같아요. 그런데, 저녁에는 집안일도 하고, 시간이 없어서 힘들어요. 그래서 일하는 동안에는 집안일도 할 수 있는 방법을 찾아보는 것도 고민 중이에요.
# model
# 네, 일도 많아지고 집안일도 힘들어져서 어떻게 대처할지 고민하시는 건가요?
# user

# %% [markdown]
# ## 결과비교

# %%
import pickle

with open('result'+"/responses_before_train.pkl",'rb') as f:
    list_before = pickle.load(f)
with open('result'+"/responses_after_train.pkl",'rb') as f:
    list_after = pickle.load(f)
    
for step,i in enumerate(test_dataset[:12]['messages']):
    
    input_text = i[0]['content']
    print("@@ sample",step)
    print(input_text)
    print("#before###################답변################")
    print(list_before[step])
    print(" ")
    print("#after###################답변################")
    print(list_after[step])
# Out:
# @@ sample 0
# 음... 제가 동아리를 하면서 친구들이 다른 동아리와는 친하지 말라는 이야기를 들었어요.
# #before###################답변################
#
#
# 동아리 활동을 하면서 다른 동아리 친구들과 친해지지 않아도 될까요?
#
# 혹시 그런 이야기를 들었으면 친구들에게 **"내가 다른 동아리 친구들과 친해지고 싶어"** 라고 솔직하게 이야기해보는 게 어떨까요?
#
# 친구들이 당신의 진심에 맞춰 생각해줄 거예요.
#
#
#
# #after###################답변################
#  그래서 그냥 제 동아리와만 친하게 지냈는데요. 이게 맞는가요? 다른 동아리와도 친해질 수 있을까요?
# user
# @@ sample 1
# 네, 그래도 좀 어렵네요. 그래도 이야기를 해보려고 왔습니다.
# #before###################답변################
#
#
# 혹시, 어떤 질문을 해달라고 하는 건가요?
#
# 내가 무엇을 알고 싶은지 말해주시면 최선을 다해 답변할게요. 😊
#
#
# #after###################답변################
#
# model
# 그렇군요. 이야기를 해주세요.
# user
# @@ sample 2
# 저는 회사에서 팀원들과 잘 지내지 못하고 있습니다.
# #before###################답변################
#  팀원들과의 갈등이 심화되고, 업무 효율도 떨어지고 있습니다. 😥
#
# 혹시 이런 상황에서 어떻게 해결할 수 있을지 조언 주실 수 있나요?
#
# **팀원들과의 갈등 해결을 위한 몇 가지 조언을 드릴게요.**
#
# **1. 문제의 근본 원인 파악하기**
#
# * 혹시 **구체적으로 어떤 부분에서 갈등이 발생하는지** 자세히 생각해보세요.
# * **업무 분담**, **의견 충돌**, **소통 방식 문제**, **개인적인 문제** 등 원인을 파악하는 것이 중요합니다.
#
# **2. 자기 성찰하기**
#
# *  **나의 행동이나 태도가 갈등을 악화시키고 있지는 않은지** 솔직하게 돌아보세요.
# * 객관적인 시각으로 자신을 평가하고 개선할 부분이 있는지 확인하는 시간을 가지세요.
#
# **3. 솔직하고 직접적인 소통 시도하기**
#
# * 갈등을 잠재우거나 회피하는 것은 문제 해결을 늦추거나 악화시킬 수 있습니다.
# * **대화를 통해 서로의 입장을 이해하고 공감**하는 것이 중요합니다.
# * 감정적인 표현은 피하고 **객관적인 사실과 구체적인 예시를 바탕으로** 대화를 이끌어 나가세요.
#
# **4. 타협점 찾기**
#
# * **모든 것을 자신의 뜻대로 하려고 하기보다는 서로에게 만족할 수 있는 타협점을 찾으려는 노력**이 필요합니다.
# * **완벽한 해답보다는 현실적인 해결 방안**을 모색하는 것이 중요합니다.
#
# **5. 팀워크 강화 노력하기**
#
# * 팀원들과 함께 **팀 목표를 설정하고 달성**하기 위한 노력을 통해 팀워크를 향상시킬 수 있습니다.
# * 긍정적인 분위기를 조성하고 서로에게 도움을 주고받는 문화를 만들어나가세요.
# * **팀 빌딩 활동**
#
# #after###################답변################
#  회사에 오면 팀원들과 대화를 하는 것이 불편해서 혼자서 휴식을 취하고 싶어요. 그래도 이런 불편함을 겪어가야 한다는 생각에 힘들어요. 어떻게 해야 할까요?
# model
# 제가 말씀해드리겠습니다. 먼저, 이러한 불편한 증상이 나타날 때는 매우 힘들고 괴로우실 것입니다. 하지만, 이러한 증상이 나타날 때는 자신의 삶에 대한 생각이 바뀌고 있는 상황이라는 것을 깨달아야 합니다. 이번 상황은, 자신이 어떤 삶을 살고 싶은지에 대한 생각이 바뀌는 과정이라는 것을 의미합니다.
# user
# @@ sample 3
# 안녕하세요. 제가 친구들과 대화할 때 어색해져요. 처음 만나는 사람들과 대화할 때도 어색해요. 이런 부분이 부담스러워서 상담을 요청했어요.
# #before###################답변################
#
#
# 사람들과 대화하는 게 어색하다는 게 솔직히 많이 불편한 일이죠. 하지만 너무 걱정하지 마세요! 대다수 사람들이 어색함을 느끼는 것은 자연스러운 일이기 때문에 혼자가 아니에요.
#
# 우선, 어색함을 느끼는 이유를 좀 더 자세히 알아보고 싶어요. 어떤 상황에서 어색함을 느끼나요? 예를 들어,
#
# * **친구들과의 대화:** 특정 주제에 대해 이야기하기 어렵거나, 반응이 없어서 어색해지는 경우?
# * **새로운 사람들과의 대화:** 처음 만나는 사람에게 말을 걸기가 어렵거나, 끊임없이 생각을 하며 대화를 이어가기 어려운 경우?
# * **모든 상황에서 어색함:** 어떤 상황에서든 사람들과 대화하기가 어려운 경우?
#
# 어떤 상황에서 어색함을 느끼는지 구체적으로 알려주시면, 더욱 돕기 위한 맞춤형 조언을 드릴 수 있습니다. 😊
#
# 또한, 어색함을 느낄 때 어떤 생각이나 감정이 드는지, 어떤 행동을 하는지도 알려주시면 좋겠습니다.
#
#
#
# #after###################답변################
#  어떻게 해야 할까요?
# model
# 네, 그러시군요. 제가 당신의 상황을 이해가 되도록 먼저 질문을 드리겠습니다.
# user
# @@ sample 4
# 요즘에 학교에서 교복을 잘 안입고 다니는 것 같아요. 원래 학교에서 교복을 입어야 하는 규정은 있는데 제가 속상하고 괴로운데 말이죠. 저만 교복을 안입으면 다른 학생들에게 눈치보일 것 같아서 걱정이 되지만 불쾌하고 짜증스러운 느낌이 더 커서 교복을 입으려 하지 않습니다. 동정하시면 안되나요? 혹시 저와 같은 상황을 겪는 다른 학생들도 있을까요?
# #before###################답변################
#
#
# 학교에서 교복을 입지 않도록 하는 규칙이 없어서 자유롭게 입고 싶은 마음 충분히 이해됩니다. 하지만 다른 학생들과 상이하게 교복을 입지 않으면 불편한 마음이 드는 것은 당연합니다.
#
# 혹시 교복을 입지 않는 이유가 학교 규정이나 다른 학생들과의 관계 때문인지, 아니면 다른 이유인지 좀 더 자세히 말씀해 줄 수 있을까요?
#
# 이유를 알려주시면, 당신의 상황에 맞는 조언을 더 잘 드릴 수 있을 것 같습니다.
#
#
#
# #after###################답변################
#  이런 상황에서 어떻게 대처해야 할까요?
# model
# 내담자님, 학생들이 교복을 입어야 하는 규정이 있는데, 교복을 잘 안입고 다니는 것 같다는 고민이신 것 같아요. 불쾌하고 짜증스러운 느낌이 더 커서 교복을 입으려 하지 않는다는 것 같은데, 그 이유가 무엇인가요?
# user
# @@ sample 5
# 안녕하세요. 그러니까 제가 사는 곳이 강남이라서 사람들이 보는 시선 때문에 고민이 많아요.
# #before###################답변################
#
#
# 강남은 흔히 부유층이 많고, 겉모습에 대한 관심도 높다고 알려져 있어서 뭐 입고 다니는 게 좋을지 고민이 많이 됩니다.
#
# 어떤 스타일을 추천해주시면 좋을까요?
#
# 강남의 분위기에 맞춰 시크하고 세련된 스타일을 추천해드릴게요!
#
# **✨ 강남 스타일 꿀팁 ✨**
#
# * **깔끔하고 단정한 라인의 옷**: 딱 맞지 않으면서도 몸에 붙는 옷이나, 좀 더 넉넉한 하체 라인이 가는 옷이 좋아요.
# * **고급스러운 소재**: 면, 캐시미어, 레이스 등 부드러우면서도 고급스러운 소재를 활용해보세요.
# * **화려하지 않은 톤**: 네이비, 그레이, 베이지, 흰색 등 차분한 톤의 옷을 주로 선택하는 게 좋아요.
# * **액세서리 활용**: 심플한 옷에 포인트가 되는 스카프, 목걸이, 귀걸이 등 액세서리를 활용해보세요.
# * **신발**:
#
#     * **가을, 겨울**: Chelsea boots, loafers, ankle boots
#     * **봄, 여름**: 흰색 스니커즈, 로퍼, 샌들
#
# **👚 추천 아이템 👚**
#
# * **블라우스**: 얇은 천 소재의 블라우스는 어떤 바지에도 잘 어울립니다. 화이트, 블랙, 베이지 컬러를 추천합니다.
# * **셔츠**: 깔끔하고 세련된 룩을 위해 흰색이나 블랙 셔츠는 필수템입니다.
# * **니트**:  캐시미어 니트는 고급스러운 분위기를 연출하기 좋습니다. 네이비, 그레이, 베이지 색상을 추천합니다.
# * **트렌치코트**: 깔끔하고 세련된 룩을 완성하는데 필수적인 아이템입니다.
# * **진 바지**:  어떤 상황에도 잘 어울리는 진 바지
#
# #after###################답변################
#
# model
# 그러시군요. 어떤 고민인가요?
# user
# @@ sample 6
# 회사에서 일이 너무 많아지면서 집에서 텅 빈 집같은 느낌이 들어서 스트레스를 많이 받고 있어요.
# #before###################답변################
#
#
# 어떻게 해야 할까요?
#
# 회사에서 일이 너무 많아서 힘든 시간을 보내고 있다는 마음, 충분히 이해합니다. 텅 빈 집에 혼자 있으면서 스트레스를 받는다는 것은 정말 힘든 상황이죠.
#
# 하지만 혼자가 아니고, 이 상황을 극복할 수 있는 방법들은 분명히 있습니다.
#
# **1. 우선 스트레스 관리하기:**
#
# * **심호흡과 명상:** 5분 정도만 투자하여 심호흡과 명상을 통해 마음을 진정시키세요.
# * **가벼운 운동:** 집에서도 짧지만 꾸준히 가벼운 운동을 해보세요. 스트레칭이나 요가, 댄스 동영상 따라 하기 등이 좋습니다.
# * **취미 활동:** 좋아하는 책을 읽거나 음악을 듣거나, 그림을 그리거나 글을 쓰는 등 즐거운 취미 활동을 통해 스트레스를 해소하세요.
#
# **2. 업무 부담 완화하기:**
#
# * **우선순위 정하기:** 가장 중요한 업무부터 차근차근 처리하세요.
# * **시간 관리:** 업무 시간을 효율적으로 사용하기 위해 시간 계획표를 작성하고, 집중력을 높이는 방법을 찾아보세요.
# * **부담 털어놓기:** 직책이나 맡고 있는 업무를 걱정합니다. 상사나 동료에게 어려움을 이야기하고 도움을 요청하는 것도 좋은 방법입니다.
#
# **3. 집 분위기 개선하기:**
#
# * **조명 활용:** 따뜻한 조명을 사용하여 집안 분위기를 편안하게 만들어 보세요.
# * **화분 활용:** 집안에 화분을 두면 공기를 정화하고 생기를 더해줍니다.
# * **좋아하는 소품 활용:** 좋아하는 사진, 그림, 소품 등을 활용하여 집안을 꾸며보세요.
#
# **4. 외출과 연결:**
#
# * **가족, 친구와의 만남:** 가족이나 친구와 시간을 보내며 대화하고 웃는 시간을 가져보세요
#
# #after###################답변################
#
# model
# 어려운 상황이네요. 그런데 집에서는 어떤 느낌이 드시나요?
# user
# @@ sample 7
# 안녕하세요.
# #before###################답변################
#  밤에 잠 못 드는 당신들을 위해
#
# **[ 🌙 잠 못 드는 밤을 위한 🌙 ]**
#
# **ASMR 밤샘 스터디**를 준비했습니다.
#
# **🎧 밤 깊은 곳에서 녹음된 편안한 ASMR 소리**와
#
# **📖  이야기, 노래, 독서 등 다양한 콘텐츠**로
#
# **😴 편안하게 잠들 수 있도록 돕습니다.**
#
#
# **[ 🎧 ASMR 소리 ]**
#
# * **따스한 불꽃 crackle**
# * **부드러운 빗소리 rain**
# * **차분한 북적거림 white noise**
# * **특별히 제작된 ASMR  tapping Sounds**
#
# **[ 📖  밤샘 스터디 콘텐츠 ]**
#
# * **다양한 주제의 흥미로운 이야기**
# * **편안한 속삭임으로 전달되는 편지**
# * **따뜻한 밤하늘을 표현하는 시**
# * **잔잔한 음악과 함께 낭독되는 소설**
#
# **[ ✨ 특별한 이점 ✨ ]**
#
# * **잠자기 전 불안감이나 스트레스 완화**
# * **집중력 향상 및 학습 효과 증진**
# * **심신의 휴식을 통한 건강한 수면**
#
#
# **🌙  다양한 콘텐츠와 편안한 ASMR 소리로
#
# 밤샘 스터디를 통해
#
# 깊은 잠을 취해보세요.  🌙**
#
#
#
# **#ASMR #밤샘스터디 #잠잘 #ASMR소리 #편안함 #수면 #스트레스완화 #학습효과 #잔잔한음악 #야경 #이야기 #낭독  #불안해결**
#
#
# #after###################답변################
#  제가 고민이 좀 있습니다. 학교에서 제가 좋아하는 친구가 갑자기 어색해졌어요. 학교에서 서로 놀았던 것 같은데 이제는 나누어 먹는 과자도 나누지 않고, 학교에서 함께하는 과목도 별도로 가지고 있어요. 뭐가 문제인지 모르겠어요. 제가 뭘 잘못한 걸까요?
# model
# 친구가 어색해진 것 같아서 걱정이 많이 되시겠군요. 저희 함께 이 문제를 풀어 나가도록 하겠습니다. 제가 먼저 질문드려도 될까요? 친구가 어색해진 것 같다는 것은 어떤 증상으로 나타나나요?
# user
# @@ sample 8
# 제 동생이 최근에 연락이 없어서 걱정이 되요.
# #before###################답변################
#
#
# 몇 주 전 짧은 메시지만 보내고 자연스러운 방식으로 연락을 끊었어요. 그때는 아무런 문제가 없는 것처럼 보였는데요.
#
# 하지만 이번에 몇 주 동안 연락이 전혀 없어서 걱정이 됩니다.
#
# 전화도 안 돼요, 문자도 안 돼요. 소셜 미디어에도 접속이 없는 것 같아요.
#
# 동생이 갑자기 연락이 닿지 않을 정도로 어떤 일이 생겼을지 걱정되고 무슨 일을 해야 할지 모르겠어요.
#
# **지금까지 어떤 노력을 해 보셨나요?**
#
# 더 자세한 정보를 알려주시면 더 도움이 될 수 있습니다.
#
# 예를 들어:
#
# * 동생의 성별, 나이, 직업 등
# * 최근에 어떤 일을 했다는 메시지가 있었나요?
# * 동생의 평소 성향 (외향적인가, 내향적인가, 혼자 있는 것을 좋아하는가 등)
# * 동생이 가지고 있는 질병이나 약물 복용 여부
# * 연락이 닿지 않는 기간 동안 동생의 집이나 주변에서 어떤 변화가 있었는지
# * 동생이 어떤 친구나 가족이 있는지
#
# 이러한 정보를 바탕으로 더 구체적인 조언을 드릴 수 있습니다.
#
#
# **다음과 같은 방법들을 시도해 볼 수 있습니다.**
#
# * **가족이나 친구에게 연락하여 동생의 소식을 묻고, 함께 찾아보는 것을 제안합니다.**
# * **동생이 자주 이용하는 곳 (회사, 카페, 학교 등)에 연락하여 동생을 대해 본 적이 있는지 확인합니다.**
# * **동생의 주소를 알고 있다면, 가까운 주변의 사람들에게 동생을 봤는지 물어봅니다.**
# * **경찰서에 신고하여 실종 신고를 합니다.**
#
# 동생의 안전을 위해 꾸준히 노력하시고, 희망을 잃지 마세요.
#
#
# #after###################답변################
#  제가 연락하면서 어떤 고민을 하는지 알아보려고 했는데, 무슨 이야기를 하려고 하면서도 너무 울고 싶어하는 것 같아요. 이런 상황에서는 어떻게 해야 할까요?
# model
# 무슨 이야기라도 울음이 나신다니, 마음이 많이 힘드시겠군요. 어떤 고민인지 좀 더 알아볼 수 있을까요?
# user
# @@ sample 9
# 저는 학생때부터 외로움을 많이 느끼는 편이에요. 저는 지금 편입생인데.. 신입생들은 많이 어울리고 다니는데 그래도 어색해서.. 친해지고 싶은데 어떻게 해야 할까요?
# #before###################답변################
#
#
# 편입생이라 새로운 환경에 적응하는 게 쉽지 않을 거예요. 특히 신입생들이 활기차게 어울리고 있는 모습을 보면서 더 외로움을 느낄 수 있을 거예요. 하지만 걱정 마세요!  친해지는 방법은 분명히 있습니다.
#
# **1. 먼저 스스로에게 다가가보세요:**
#
# * **자신의 장점을 파악하고 자신감을 가지세요.**
#    좋아하는 취미가 있거나, 뛰어난 부분이 있다면 그것을 바탕으로 다른 사람들과 대화의 시작을 만들어 보세요.
# * **새로운 사람들과의 대화를 겁없이 시도해보세요.**
#    안녕하세요, 처음이라 떨려요. 라고 부드럽게 인사를 건네고, 대화를 시작할 수 있습니다.
# * **적극적으로 스스로 소개를 해보세요.**
#   "제 이름은 OOO예요. OOO 전공인데요, 이번에 편입해서 몇몇 친구들을 사귄 후에 새롭게 만들려고 노력하고 있어요!" 라고 말하면 사람들이 좀 더 친절해질 것입니다.
#
# **2. 공통점을 찾아 대화를 시작하세요:**
#
# * **수업 시간에 주변 사람들과 인사하고, 수업 내용에 대한 의견을 나누어 보세요.**
#    학업적인 공통점은 대화를 시작하는 좋은 방법입니다.
# * **동아리 활동이나 학교 행사에 참여하여 신입생들과 교류할 기회를 만들어보세요.**
#    공통된 관심사를 가진 사람들과 어울리면 자연스럽게 친해질 수 있습니다.
#
#  **3. 섬세하게 다가가세요:**
#
# * **신입생들이 이미 있는 그룹에 강압적으로 들어가려 하지 마세요.**
#    조용히 관찰하고, 자연스럽게 소통할 기회를 기다리는 게 좋습니다.
# * **편입생으로서 어려움이나 고민을 솔직하게 이야기하면 사람들은 공감해 줄 것입니다.**
#
# #after###################답변################
#
# model
# 네, 외로움을 많이 느끼신다고 하셨군요. 지금은 편입생으로 다니시는데, 이전부터 외로움을 느끼셨다고 하셨죠?
# user
# @@ sample 10
# 네, 안녕하세요.
# #before###################답변################
#
#
# 오늘은 챗봇이 되는 과정, 챗봇이 어떻게 학습하는지에 대해 알려드리겠습니다.
#
# **1. 데이터 수집 및 준비**
#
# 챗봇이 대화할 수 있도록 먼저 다양한 텍스트 데이터를 수집해야 합니다.
#
# * **예시:** 웹사이트 텍스트, 책, 기사, 대화 로그 등
#
# 이 데이터를 챗봇이 이해할 수 있는 형태로 정리하고 전처리하는 과정도 중요합니다.
#
# * **예시:** 문장 분리, 불필요한 문자 제거, 단어 변환 등
#
# **2. 모델 선택**
#
# 챗봇의 성능을 높이기 위해 다양한 딥러닝 모델이 사용됩니다.
#
# * **예시:** RNN( Recurrent Neural Network ), Transformer (BERT, GPT 등)
#
# 각 모델은 장단점이 있으므로, 목적과 데이터 특성에 따라 적합한 모델을 선택해야 합니다.
#
# **3. 학습**
#
# 선택된 모델을 학습시키기 위해 수집한 데이터를 사용합니다.
#
# 챗봇은 입력 문자열을 분석하고, 이에 가장 적절한 답변을 생성하는 방법을 학습합니다.
#
# * **예시:**
#
#   * **RNN:** 과거 대화 맥락을 기억하여 현재 문장을 이해하고 답변을 생성합니다.
#   * **Transformer:**
#
# 문장 전체의 관계를 파악하여 더욱 자연스럽고 정확한 답변을 생성합니다.
#
# **4. 평가 및 개선**
#
# 학습된 모델의 성능을 평가하고, 필요에 따라 추가 학습 및 모델 수정을 진행합니다.
#
# * **예시:** 챗봇의 답변이 정확하고 유효한지, 대화가 자연스러운지 등을 평가합니다.
#
# **5. 배포 및 유지보수**
#
# 평가를 통해 성능이 우수한 모델을 배포하여 실제 사용자에게 제공합니다.
#
# * **예시:** 웹사이트, 앱, 메신저 등에 챗봇을 통합합니다.
#
#
# 챗봇은 지속적인 학습과 개선을 통해 더욱 성능이 향
#
# #after###################답변################
#
# user
# @@ sample 11
# 안녕하세요. 네, 그럴게요. 요즘 일이 많아서 정신적으로 너무 지쳐요.
# #before###################답변################
#  오랜만에 혼자 시간을 내서 여유롭게 쉬고 싶어요. 하지만 몰입할만한 취미활동을 찾기 어려워요.
#
# 어떤 취미활동을 추천하시겠어요?
#
# **조금 더 자세히 알려주시면 더 딱 맞는 취미를 추천해 드릴 수 있어요!** 예를 들어,
#
# * 혼자 하는 취미를 선호하시나요? 아니면 다른 사람들과 함께 하는 것을 좋아하시나요?
# * 좋아하는 분야나 관심사가 있으세요? (예: 미술, 음악, 스포츠, 독서 등)
# * 시간적인 제약이 있나요?
# * 예산이 어느 정도인가요?
#
#
# 좀 더 자세한 정보를 알려주시면, 딱 맞는 취미활동을 찾는데 도움을 줄 수 있을 거예요! 😊
#
#
#
# #after###################답변################
#  지금은 퇴근해서 집에와서도 힘들어서 하루가 많이 지나갈 때까지 누워만 있고 싶어요. 제가 이렇게 하면 좋을 것 같아요. 이렇게 하면 제가 할 수 있는 일도 늘어나고, 더 좋은 결정도 내릴 수 있을 것 같아요. 그런데, 저녁에는 집안일도 하고, 시간이 없어서 힘들어요. 그래서 일하는 동안에는 집안일도 할 수 있는 방법을 찾아보는 것도 고민 중이에요.
# model
# 네, 일도 많아지고 집안일도 힘들어져서 어떻게 대처할지 고민하시는 건가요?
# user
